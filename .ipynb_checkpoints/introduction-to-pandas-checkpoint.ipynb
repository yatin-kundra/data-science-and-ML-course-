# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 2 types of datatypes in pandas 
series = pd.Series(["BMW", "Toyota", "Audi", "Bugatti"])

# %% [markdown]
# # series
# series is a 1-dimentional

# %%
series
# Out:
# 0        BMW
# 1     Toyota
# 2       Audi
# 3    Bugatti
# dtype: object

# %%
colors = pd.Series(["red", "blue", "yellow", "violet"])

# %%
colors
# Out:
# 0       red
# 1      blue
# 2    yellow
# 3    violet
# dtype: object

# %% [markdown]
# # dataframes
# dataframes are 2-dimentional

# %%
car_data = pd.DataFrame({"car make" : series, "color": colors})     # takes dictionary as inpu
car_data
# Out:
#   car make   color
# 0      BMW     red
# 1   Toyota    blue
# 2     Audi  yellow
# 3  Bugatti  violet

# %%
# importing data 
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# row is axis = 0
#
# coloumn is axis = 1

# %%
car_sales.to_csv("exported-car-sales_data.csv")

# %%
exported_data = pd.read_csv("exported-car-sales_data.csv")

# %%
exported_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# we got 2 index columns so if we don't want that to happen we need to tell index = False
# while we are exproitng data

# %%
car_sales.to_csv("exported-car-sales_data.csv", index = False)    # we will not have 2 index columns

# %% [markdown]
# ## describing data

# %%
#attribute    -> gives information about something
car_sales.dtypes

#function     -> do steps that it has been written to do, i.e thay are going to perform some kind of operations
# car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns       # gives columns of the table we are working with and their data type
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
columns = car_sales.columns

# %%
columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index      # tells index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales      # showing car_sales table , its going from 0 t0 10 taking 1 step.
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()

# tells some information about the columns of table with data type integer
# price is not here cause its not of data type int , maybe because it might have been formated in a diffrent way than others
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean()
# Out:
# C:\Users\ykund\AppData\Local\Temp\ipykernel_6920\4073448239.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([2150,5165,6486,8435]).mean()
car_prices
# Out:
# 5559.0

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## viewing and selecting data

# %%
car_sales.head()    # returns first 5 rows of the data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()    # returns last 5 rows of the data
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
    # .loc   &   .iloc

# %%
animals = pd.Series(["dog", "cat", "snake", "panda", "lion"])
animals
# Out:
# 0      dog
# 1      cat
# 2    snake
# 3    panda
# 4     lion
# dtype: object

# %%
animals = pd.Series(["dog", "cat", "snake", "panda", "lion"], 
                   index = [0,3,6,3,5])
animals

# we can assign index whatever we want to our data
# Out:
# 0      dog
# 3      cat
# 6    snake
# 3    panda
# 5     lion
# dtype: object

# %%
animals.loc[3]     # loc , means locaton so it will return what is at the index it has been passed to , here it refers 
# index no.
# Out:
# 3      cat
# 3    panda
# dtype: object

# %%
animals.loc[6]
# Out:
# 'snake'

# %%
car_sales.loc[2]
# Out:
# Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# Name: 2, dtype: object

# %%
# iloc

# %%
animals
# Out:
# 0      dog
# 3      cat
# 6    snake
# 3    panda
# 5     lion
# dtype: object

# %%
animals.iloc[3]     # iloc tells position i.e. it gives value at the index that we give in this case that is 3 , it counts for that
# that index
# Out:
# 'panda'

# %%
animals.iloc[:3]      # doesnot include position 3
# Out:
# 0      dog
# 3      cat
# 6    snake
# dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Make"].iloc[:5]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make    # is working because there is no space between the name of column name Make

# car_sales.Odeometer (KM)          # this will not work as there is space between Odeometer and (KM)
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]     # condition
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# groupby
car_sales.groupby("Make").mean()
# Out:
# C:\Users\ykund\AppData\Local\Temp\ipykernel_6920\867748448.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   car_sales.groupby("Make").mean()
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# visulaization 
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
# visulaization 

# hsitogram

car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Price
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales["Price"].dtype    # telling that object is of type object
# Out:
# dtype('int32')

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.00]', '').astype(int)

# str tells get the string from price 
# replace  $ , .    to   ''      -> replace to nothing 
# .astype(int)    -> means change the data type to int
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.00]', '').astype(int)
#       3 # str tells get the string from price
#       4 # replace  $ , .    to   ''      -> replace to nothing
#       5 # .astype(int)    -> means change the data type to int
#       6 get_ipython().system('clear')
#
# File ~\Desktop\COMPUTER_SCIENCE\Machine Learning\sample_project_1\env\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()     # .srt to tap into the string value     and   lower() to turn into lower case
# eveything that can be done on python string can be done on string in pandas

# to save changes we need to reassign those changes
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing           # NaN is telling that this cell is empty
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# let's say we want to fill these empty cells of Odometer with the mean of the Odometer values , which in reality is not a good
# practice 

car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# if we want to delete the row with the missing values

car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# ## careting a column for the existing table

# %% [markdown]
# seates_column = pd.Series([5,5,5,5,5])

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Seates"] = seates_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates
# 0  Toyota  White         150043      4   $4,000.00     5.0
# 1   Honda    Red          87899      4   $5,000.00     5.0
# 2  Toyota   Blue          32549      3   $7,000.00     5.0
# 3     BMW  Black          11179      5  $22,000.00     5.0
# 4  Nissan  White         213095      4   $3,500.00     5.0
# 5  Toyota  Green          99213      4   $4,500.00     NaN
# 6   Honda   Blue          45698      4   $7,500.00     NaN
# 7   Honda   Blue          54738      4   $7,000.00     NaN
# 8  Toyota  White          60000      4   $6,250.00     NaN
# 9  Nissan  White          31600      4   $9,700.00     NaN

# %%
car_sales["Seates"].fillna(5, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates
# 0  Toyota  White         150043      4   $4,000.00     5.0
# 1   Honda    Red          87899      4   $5,000.00     5.0
# 2  Toyota   Blue          32549      3   $7,000.00     5.0
# 3     BMW  Black          11179      5  $22,000.00     5.0
# 4  Nissan  White         213095      4   $3,500.00     5.0
# 5  Toyota  Green          99213      4   $4,500.00     5.0
# 6   Honda   Blue          45698      4   $7,500.00     5.0
# 7   Honda   Blue          54738      4   $7,000.00     5.0
# 8  Toyota  White          60000      4   $6,250.00     5.0
# 9  Nissan  White          31600      4   $9,700.00     5.0

# %%
fuel_economy = [5.4, 8.5, 9.8, 6.3, 8.2, 7.2, 4.5, 6.4, 8.3, 5.5]
car_sales["fuel pe 100 KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM
# 0  Toyota  White         150043      4   $4,000.00     5.0             5.4
# 1   Honda    Red          87899      4   $5,000.00     5.0             8.5
# 2  Toyota   Blue          32549      3   $7,000.00     5.0             9.8
# 3     BMW  Black          11179      5  $22,000.00     5.0             6.3
# 4  Nissan  White         213095      4   $3,500.00     5.0             8.2
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.2
# 6   Honda   Blue          45698      4   $7,500.00     5.0             4.5
# 7   Honda   Blue          54738      4   $7,000.00     5.0             6.4
# 8  Toyota  White          60000      4   $6,250.00     5.0             8.3
# 9  Nissan  White          31600      4   $9,700.00     5.0             5.5

# %%
car_sales["total fuel (L)"] = car_sales["fuel pe 100 KM"]/100 * car_sales["Odometer (KM)"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             5.4
# 1   Honda    Red          87899      4   $5,000.00     5.0             8.5
# 2  Toyota   Blue          32549      3   $7,000.00     5.0             9.8
# 3     BMW  Black          11179      5  $22,000.00     5.0             6.3
# 4  Nissan  White         213095      4   $3,500.00     5.0             8.2
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.2
# 6   Honda   Blue          45698      4   $7,500.00     5.0             4.5
# 7   Honda   Blue          54738      4   $7,000.00     5.0             6.4
# 8  Toyota  White          60000      4   $6,250.00     5.0             8.3
# 9  Nissan  White          31600      4   $9,700.00     5.0             5.5
#
#    total fuel (L)
# 0        8102.322
# 1        7471.415
# 2        3189.802
# 3         704.277
# 4       17473.790
# 5        7143.336
# ...

# %%
# creating a column from a single value
car_sales["no of wheels"] = 4
car_sales
car_sales["no of wheelsss"] = 6

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             5.4
# 1   Honda    Red          87899      4   $5,000.00     5.0             8.5
# 2  Toyota   Blue          32549      3   $7,000.00     5.0             9.8
# 3     BMW  Black          11179      5  $22,000.00     5.0             6.3
# 4  Nissan  White         213095      4   $3,500.00     5.0             8.2
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.2
# 6   Honda   Blue          45698      4   $7,500.00     5.0             4.5
# 7   Honda   Blue          54738      4   $7,000.00     5.0             6.4
# 8  Toyota  White          60000      4   $6,250.00     5.0             8.3
# 9  Nissan  White          31600      4   $9,700.00     5.0             5.5
#
#    total fuel (L)  no of wheels  no of wheelsss
# 0        8102.322             4               6
# ...

# %%
# to drop a column that we don't want
car_sales.drop("no of wheelsss", axis=1, inplace= True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             5.4
# 1   Honda    Red          87899      4   $5,000.00     5.0             8.5
# 2  Toyota   Blue          32549      3   $7,000.00     5.0             9.8
# 3     BMW  Black          11179      5  $22,000.00     5.0             6.3
# 4  Nissan  White         213095      4   $3,500.00     5.0             8.2
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.2
# 6   Honda   Blue          45698      4   $7,500.00     5.0             4.5
# 7   Honda   Blue          54738      4   $7,000.00     5.0             6.4
# 8  Toyota  White          60000      4   $6,250.00     5.0             8.3
# 9  Nissan  White          31600      4   $9,700.00     5.0             5.5
#
#    total fuel (L)  no of wheels
# 0        8102.322             4
# 1        7471.415             4
# 2        3189.802             4
# ...

# %%
car_sales["air check"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             5.4
# 1   Honda    Red          87899      4   $5,000.00     5.0             8.5
# 2  Toyota   Blue          32549      3   $7,000.00     5.0             9.8
# 3     BMW  Black          11179      5  $22,000.00     5.0             6.3
# 4  Nissan  White         213095      4   $3,500.00     5.0             8.2
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.2
# 6   Honda   Blue          45698      4   $7,500.00     5.0             4.5
# 7   Honda   Blue          54738      4   $7,000.00     5.0             6.4
# 8  Toyota  White          60000      4   $6,250.00     5.0             8.3
# 9  Nissan  White          31600      4   $9,700.00     5.0             5.5
#
#    total fuel (L)  no of wheels  air check
# 0        8102.322             4       True
# 1        7471.415             4       True
# ...

# %%
# to shuffel the data so that we can give out model as much general data we can
car_sales = car_sales.sample(frac=1)      # this will shuffel our data
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             5.4
# 5  Toyota  Green          99213      4   $4,500.00     5.0             7.2
# 4  Nissan  White         213095      4   $3,500.00     5.0             8.2
# 3     BMW  Black          11179      5  $22,000.00     5.0             6.3
# 1   Honda    Red          87899      4   $5,000.00     5.0             8.5
# 2  Toyota   Blue          32549      3   $7,000.00     5.0             9.8
# 9  Nissan  White          31600      4   $9,700.00     5.0             5.5
# 7   Honda   Blue          54738      4   $7,000.00     5.0             6.4
# 6   Honda   Blue          45698      4   $7,500.00     5.0             4.5
# 8  Toyota  White          60000      4   $6,250.00     5.0             8.3
#
#    total fuel (L)  no of wheels  air check
# 0        8102.322             4       True
# 5        7143.336             4       True
# ...

# %%
# if you wnat to expirent on only 50% of the data
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM  \
# 9  Nissan  White          31600      4   $9,700.00     5.0             5.5
# 3     BMW  Black          11179      5  $22,000.00     5.0             6.3
# 8  Toyota  White          60000      4   $6,250.00     5.0             8.3
# 6   Honda   Blue          45698      4   $7,500.00     5.0             4.5
# 2  Toyota   Blue          32549      3   $7,000.00     5.0             9.8
#
#    total fuel (L)  no of wheels  air check
# 9        1738.000             4       True
# 3         704.277             4       True
# 8        4980.000             4       True
# 6        2056.410             4       True
# 2        3189.802             4       True

# %%
# to reset the index as after the shuffel they are out of order
car_sales.reset_index(drop = True, inplace= True)
# drop = True means we dont want the previous index , that is shuffed so drop that

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM  \
# 0  Toyota  White         150043      4   $4,000.00     5.0             5.4
# 1  Toyota  Green          99213      4   $4,500.00     5.0             7.2
# 2  Nissan  White         213095      4   $3,500.00     5.0             8.2
# 3     BMW  Black          11179      5  $22,000.00     5.0             6.3
# 4   Honda    Red          87899      4   $5,000.00     5.0             8.5
# 5  Toyota   Blue          32549      3   $7,000.00     5.0             9.8
# 6  Nissan  White          31600      4   $9,700.00     5.0             5.5
# 7   Honda   Blue          54738      4   $7,000.00     5.0             6.4
# 8   Honda   Blue          45698      4   $7,500.00     5.0             4.5
# 9  Toyota  White          60000      4   $6,250.00     5.0             8.3
#
#    total fuel (L)  no of wheels  air check
# 0        8102.322             4       True
# 1        7143.336             4       True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seates  fuel pe 100 KM  \
# 0  Toyota  White      93776.875      4   $4,000.00     5.0             5.4
# 1  Toyota  Green      62008.125      4   $4,500.00     5.0             7.2
# 2  Nissan  White     133184.375      4   $3,500.00     5.0             8.2
# 3     BMW  Black       6986.875      5  $22,000.00     5.0             6.3
# 4   Honda    Red      54936.875      4   $5,000.00     5.0             8.5
# 5  Toyota   Blue      20343.125      3   $7,000.00     5.0             9.8
# 6  Nissan  White      19750.000      4   $9,700.00     5.0             5.5
# 7   Honda   Blue      34211.250      4   $7,000.00     5.0             6.4
# 8   Honda   Blue      28561.250      4   $7,500.00     5.0             4.5
# 9  Toyota  White      37500.000      4   $6,250.00     5.0             8.3
#
#    total fuel (L)  no of wheels  air check
# 0        8102.322             4       True
# 1        7143.336             4       True
# ...
